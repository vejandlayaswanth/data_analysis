# %%
# !pip install pandas

# %%
import numpy as np 
import pandas as pd

# %%
movie_data = pd.read_csv("/Users/yaswanthkumarvejandla/Downloads/DATA SCIENCE & AI /projects/IMDB_MOVIE_RATING/Movie-Rating.csv")

# %%
movie_data
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movie_data.head(6)
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
# 5                   2012     Action                         39
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009
# 5                  63                 200             2009

# %%
type(movie_data)
# Out:
# pandas.core.frame.DataFrame

# %%
len(movie_data)
# Out:
# 559

# %%
movie_data.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie_data.shape
# Out:
# (559, 6)

# %%
movie_data.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movie_data.columns = ['Film','Genre','CriticRating','AudienceRating','BudgetMillions','Year']

# %%
movie_data.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movie_data["Film"] = movie_data["Film"].astype("category")

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movie_data["Genre"] = movie_data["Genre"].astype("category")

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %%
movie_data
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
# !pip install matplotlib
# !pip install seaborn

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # working with JOINTS

# %%
sns.jointplot(data = movie_data , x ='CriticRating' , y = 'AudienceRating', kind = 'reg' )
plt.show()

# %%
sns.jointplot(data = movie_data , x ='CriticRating' , y = 'AudienceRating', kind = 'hex' )
plt.show()

# %%
sns.jointplot(data = movie_data , x ='CriticRating' , y = 'AudienceRating', kind = 'scatter' )
plt.show()

# %% [markdown]
# # Histograms

# %%
sns.distplot(movie_data['AudienceRating'])
plt.show()

# %%
sns.set_style('darkgrid')
sns.distplot(movie_data.AudienceRating, bins =10)
plt.show()

# %%
plt.hist(movie_data.AudienceRating , bins=26)
plt.show()

# %%
movie_data.head(26)
# Out:
#                                  Film      Genre  CriticRating  \
# 0               (500) Days of Summer      Comedy            87
# 1                         10,000 B.C.  Adventure             9
# 2                          12 Rounds      Action            30
# 3                           127 Hours  Adventure            93
# 4                           17 Again      Comedy            55
# 5                                2012     Action            39
# 6                          27 Dresses     Comedy            40
# 7                    30 Days of Night     Horror            50
# 8                  30 Minutes or Less     Comedy            43
# 9                               50/50     Comedy            93
# 10                         88 Minutes      Drama             5
# 11                 A Dangerous Method      Drama            79
# 12          A Nightmare on Elm Street     Horror            13
# 13                     A Serious Man       Drama            89
# ...

# %% [markdown]
# # working with filter

# %%
plt.hist(movie_data[movie_data.Genre=='Action'].BudgetMillions, bins=20)
plt.hist(movie_data[movie_data.Genre=='Comedy'].BudgetMillions, bins=20)
plt.hist(movie_data[movie_data.Genre=='Adventure'].BudgetMillions, bins=20)
plt.hist(movie_data[movie_data.Genre=='Romance'].BudgetMillions, bins=20)
plt.legend()
plt.show()

# %%
plt.hist([movie_data[movie_data.Genre == 'Action'].BudgetMillions,\
          movie_data[movie_data.Genre == 'Drama'].BudgetMillions, \
          movie_data[movie_data.Genre == 'Thriller'].BudgetMillions, \
          movie_data[movie_data.Genre == 'Comedy'].BudgetMillions],
         bins = 20, stacked = True)
plt.show()

# %%
for gen in movie_data.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
sns.lmplot(data=movie_data , x='CriticRating',y='AudienceRating', fit_reg=False)
plt.show()

# %%
sns.lmplot(data=movie_data , x='CriticRating',y='AudienceRating', fit_reg=False , hue='Genre' , height  = 10, aspect=1)
plt.show()

# %%
sns.kdeplot(x= movie_data['CriticRating'],y=movie_data['AudienceRating'])
plt.show()

# %%
sns.kdeplot(x=movie_data['CriticRating'],y=movie_data['AudienceRating'],  shade_lowest = False , cmap ='Reds')
plt.show()

# %%
sns.kdeplot(x=movie_data['CriticRating'],y=movie_data['AudienceRating'],  shade_lowest = False , cmap ='Greens')
plt.show()

# %%
f, axes = plt.subplots(1, 2, figsize=(12, 6))

sns.kdeplot(x=movie_data['BudgetMillions'], y=movie_data['AudienceRating'], ax=axes[0])
sns.kdeplot(x=movie_data['BudgetMillions'], y=movie_data['CriticRating'], ax=axes[1])

plt.show()

# %% [markdown]
# # Box plot

# %%
sns.boxplot(x=movie_data['Genre'], y=movie_data['CriticRating'])
plt.show()

# %%
sns.boxplot(data=movie_data , x='Genre' , y ="CriticRating")
plt.show()

# %% [markdown]
# # Violin plot

# %%
sns.violinplot(data=movie_data , x='Genre' , y ="CriticRating")
plt.show()

# %% [markdown]
# # CREATING FACET GRID

# %%
k=sns.FacetGrid(movie_data,row = 'Genre',col='Year',hue='Genre')
k=k.map(plt.scatter,'CriticRating','AudienceRating')
plt.show()

# %%
g =sns.FacetGrid (movie_data, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillions') #scatterplots are mapped in facetgrid
plt.show()

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(movie_data['BudgetMillions'],movie_data['AudienceRating'],ax=axes[0,0])
k2 = sns.kdeplot(movie_data['BudgetMillions'],movie_data['AudienceRating'],ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movie_data[movie_data.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

k4 = sns.kdeplot(movie_data.CriticRating,movie_data.AudienceRating,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(movie_data.CriticRating, movie_data.AudienceRating,cmap='Reds',ax = axes[1,1])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 4
#       1 sns.set_style('darkgrid')
#       2 f, axes = plt.subplots (2,2, figsize = (15,15))
# ----> 4 k1 = sns.kdeplot(movie_data['BudgetMillions'],movie_data['AudienceRating'],ax=axes[0,0])
#       5 k2 = sns.kdeplot(movie_data['BudgetMillions'],movie_data['AudienceRating'],ax = axes[0,1])
#       7 k1.set(xlim=(-20,160))
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots(2, 2, figsize=(15, 15))

# KDE Plots with keyword arguments
k1 = sns.kdeplot(x=movie_data['BudgetMillions'], y=movie_data['AudienceRating'], ax=axes[0, 0])
k2 = sns.kdeplot(x=movie_data['BudgetMillions'], y=movie_data['AudienceRating'], ax=axes[0, 1])

k1.set(xlim=(-20, 160))
k2.set(xlim=(-20, 160))

# Violin Plot
z = sns.violinplot(data=movie_data[movie_data.Genre == 'Drama'],
                   x='Year', y='CriticRating', ax=axes[1, 0])

# KDE Plot with shading and updated keyword arguments
k4 = sns.kdeplot(x=movie_data['CriticRating'], y=movie_data['AudienceRating'],
                 fill=True, cmap='Reds', ax=axes[1, 1])
# Overlay another KDE line plot
k4b = sns.kdeplot(x=movie_data['CriticRating'], y=movie_data['AudienceRating'],
                  cmap='Reds', ax=axes[1, 1])

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Drop rows with missing values in relevant columns
movie_data_clean = movie_data.dropna(subset=['BudgetMillions', 'AudienceRating', 'CriticRating', 'Genre', 'Year'])

sns.set_style('darkgrid')
f, axes = plt.subplots(2, 2, figsize=(15, 15))

# First KDE plot
k1 = sns.kdeplot(
    data=movie_data_clean, x='BudgetMillions', y='AudienceRating', ax=axes[0, 0], fill=True
)
k1.set(xlim=(-20, 160))

# Second KDE plot (duplicate of first, maybe change?)
k2 = sns.kdeplot(
    data=movie_data_clean, x='BudgetMillions', y='AudienceRating', ax=axes[0, 1], fill=True
)
k2.set(xlim=(-20, 160))

# Violin plot (ensure 'Drama' exists)
drama_data = movie_data_clean[movie_data_clean.Genre == 'Drama']
if not drama_data.empty:
    sns.violinplot(data=drama_data, x='Year', y='CriticRating', ax=axes[1, 0])
else:
    axes[1, 0].text(0.5, 0.5, "No Drama data", ha='center')

# Final KDE plot: Critic vs Audience Rating
k4 = sns.kdeplot(
    data=movie_data_clean, x='CriticRating', y='AudienceRating', ax=axes[1, 1], fill=True, cmap='Reds'
)
sns.kdeplot(
    data=movie_data_clean, x='CriticRating', y='AudienceRating', ax=axes[1, 1], cmap='Reds'
)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cleaned dataset to avoid NaNs
movies_clean = movie_data.dropna(subset=['BudgetMillions', 'AudienceRating', 'CriticRating', 'Genre', 'Year'])

# Set dark theme with custom background
sns.set_style('dark', {'axes.facecolor': 'black'})

f, axes = plt.subplots(2, 2, figsize=(15, 15))

# Plot [0, 0]: Budget vs AudienceRating with 'inferno' and 'cool'
sns.kdeplot(
    data=movies_clean, x='BudgetMillions', y='AudienceRating',
    fill=True, cmap='inferno', ax=axes[0, 0]
)
sns.kdeplot(
    data=movies_clean, x='BudgetMillions', y='AudienceRating',
    cmap='cool', ax=axes[0, 0]
)
axes[0, 0].set_xlim(-20, 160)

# Plot [0, 1]: Budget vs CriticRating with 'inferno' and 'cool'
sns.kdeplot(
    data=movies_clean, x='BudgetMillions', y='CriticRating',
    fill=True, cmap='inferno', ax=axes[0, 1]
)
sns.kdeplot(
    data=movies_clean, x='BudgetMillions', y='CriticRating',
    cmap='cool', ax=axes[0, 1]
)
axes[0, 1].set_xlim(-20, 160)

# Plot [1, 0]: Violin plot for Drama genre
drama_data = movies_clean[movies_clean.Genre == 'Drama']
if not drama_data.empty:
    sns.violinplot(data=drama_data, x='Year', y='CriticRating', ax=axes[1, 0])
else:
    axes[1, 0].text(0.5, 0.5, 'No Drama data', ha='center', va='center')

# Plot [1, 1]: CriticRating vs AudienceRating with Blues_r and gist_gray_r
sns.kdeplot(
    data=movies_clean, x='CriticRating', y='AudienceRating',
    fill=True, cmap='Blues_r', ax=axes[1, 1]
)
sns.kdeplot(
    data=movies_clean, x='CriticRating', y='AudienceRating',
    cmap='gist_gray_r', ax=axes[1, 1]
)

plt.tight_layout()
plt.show()
